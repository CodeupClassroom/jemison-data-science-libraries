# %%
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

# %%
# a dataframe is composed of series
# each series is a column
# but the df itself is more than a list of series
# the df itself has its own functionality on top
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
# df.column_name returns that specific series
df.name
# Out:
# 0       Sally
# 1        Jane
# 2       Suzie
# 3       Billy
# 4         Ada
# 5        John
# 6      Thomas
# 7       Marie
# 8      Albert
# 9     Richard
# 10      Isaac
# 11       Alan
# Name: name, dtype: object

# %%
# the dataframe itself has its own method and functionality
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     12 non-null     object
#  1   math     12 non-null     int64
#  2   english  12 non-null     int64
#  3   reading  12 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 512.0+ bytes

# %%
df.dtypes
# Out:
# name       object
# math        int64
# english     int64
# reading     int64
# dtype: object

# %%
df.columns
# Out:
# Index(['name', 'math', 'english', 'reading'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
# .describe provides summary stats on our numeric columns
df.describe()
# Out:
#             math    english    reading
# count  12.000000  12.000000  12.000000
# mean   84.833333  77.666667  86.500000
# std    11.134168  13.371158   9.643651
# min    62.000000  62.000000  67.000000
# 25%    78.500000  63.750000  80.750000
# 50%    90.000000  77.500000  89.000000
# 75%    92.250000  86.750000  93.250000
# max    98.000000  99.000000  98.000000

# %% [markdown]
# ## Why DataFrames?
# - Rectangular data consisting of columns and rows
# - Dataframes enjoy functionality above/beyond series
# - Dataframes are a container for series

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
# How to access a specific column
# df.column_name
# df["column_name"]
df.math.head()
# Out:
# 0    62
# 1    88
# 2    94
# 3    98
# 4    77
# Name: math, dtype: int64

# %%
df["math"].head()
# Out:
# 0    62
# 1    88
# 2    94
# 3    98
# 4    77
# Name: math, dtype: int64

# %%
# Making a new column from scratch, we'll need to use the ["column_name"] syntax
df["cohort"] = "Jemison"
df
# Out:
#        name  math  english  reading   cohort
# 0     Sally    62       85       80  Jemison
# 1      Jane    88       79       67  Jemison
# 2     Suzie    94       74       95  Jemison
# 3     Billy    98       96       88  Jemison
# 4       Ada    77       92       98  Jemison
# 5      John    79       76       93  Jemison
# 6    Thomas    82       64       81  Jemison
# 7     Marie    93       63       90  Jemison
# 8    Albert    92       62       87  Jemison
# 9   Richard    69       80       94  Jemison
# 10    Isaac    92       99       93  Jemison
# 11     Alan    92       62       72  Jemison

# %%
# To make a new column
# df["column_name"] = value
df["campus"] = "San Antonio"

# %%
# Show the students who are making As in math
# df.math >= 90 returns a series of booleans 
df.math >= 90
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9     False
# 10     True
# 11     True
# Name: math, dtype: bool

# %% [markdown]
# ## Once you have your array/Series of booleans, you have the keys to the castle
# - we can filter our results
# - `df[df.column > 90]`

# %%
# SELECT * from df where math >= 90
# The variable or expression that produces the array booleans
# goes in the brackets to filter our results
df[df.math >= 90]
# Out:
#       name  math  english  reading   cohort       campus
# 2    Suzie    94       74       95  Jemison  San Antonio
# 3    Billy    98       96       88  Jemison  San Antonio
# 7    Marie    93       63       90  Jemison  San Antonio
# 8   Albert    92       62       87  Jemison  San Antonio
# 10   Isaac    92       99       93  Jemison  San Antonio
# 11    Alan    92       62       72  Jemison  San Antonio

# %%
# What if we need to store math >= 90 as its own column
# Let's build a new column
# is_math_honors
df["math_honors"] = df.math >= 90
df
# Out:
#        name  math  english  reading   cohort       campus  math_honors
# 0     Sally    62       85       80  Jemison  San Antonio        False
# 1      Jane    88       79       67  Jemison  San Antonio        False
# 2     Suzie    94       74       95  Jemison  San Antonio         True
# 3     Billy    98       96       88  Jemison  San Antonio         True
# 4       Ada    77       92       98  Jemison  San Antonio        False
# 5      John    79       76       93  Jemison  San Antonio        False
# 6    Thomas    82       64       81  Jemison  San Antonio        False
# 7     Marie    93       63       90  Jemison  San Antonio         True
# 8    Albert    92       62       87  Jemison  San Antonio         True
# 9   Richard    69       80       94  Jemison  San Antonio        False
# 10    Isaac    92       99       93  Jemison  San Antonio         True
# 11     Alan    92       62       72  Jemison  San Antonio         True

# %%
df["english_honors"] = df.english >= 90
df
# Out:
#        name  math  english  reading   cohort       campus  math_honors  \
# 0     Sally    62       85       80  Jemison  San Antonio        False
# 1      Jane    88       79       67  Jemison  San Antonio        False
# 2     Suzie    94       74       95  Jemison  San Antonio         True
# 3     Billy    98       96       88  Jemison  San Antonio         True
# 4       Ada    77       92       98  Jemison  San Antonio        False
# 5      John    79       76       93  Jemison  San Antonio        False
# 6    Thomas    82       64       81  Jemison  San Antonio        False
# 7     Marie    93       63       90  Jemison  San Antonio         True
# 8    Albert    92       62       87  Jemison  San Antonio         True
# 9   Richard    69       80       94  Jemison  San Antonio        False
# 10    Isaac    92       99       93  Jemison  San Antonio         True
# 11     Alan    92       62       72  Jemison  San Antonio         True
#
#     english_honors
# 0            False
# 1            False
# 2            False
# 3             True
# 4             True
# 5            False
# 6            False
# 7            False
# 8            False
# 9            False
# 10            True
# 11           False

# %%
df["reading_honors"] = df.reading >= 90
df.head()
# Out:
#     name  math  english  reading   cohort       campus  math_honors  \
# 0  Sally    62       85       80  Jemison  San Antonio        False
# 1   Jane    88       79       67  Jemison  San Antonio        False
# 2  Suzie    94       74       95  Jemison  San Antonio         True
# 3  Billy    98       96       88  Jemison  San Antonio         True
# 4    Ada    77       92       98  Jemison  San Antonio        False
#
#    english_honors  reading_honors
# 0           False           False
# 1           False           False
# 2           False            True
# 3            True           False
# 4            True            True

# %%
# What about creating an all_honors column
# create a new column called all_honors
df["all_honors"] = df.english_honors & df.math_honors & df.reading_honors
df.head()
# Out:
#     name  math  english  reading   cohort       campus  math_honors  \
# 0  Sally    62       85       80  Jemison  San Antonio        False
# 1   Jane    88       79       67  Jemison  San Antonio        False
# 2  Suzie    94       74       95  Jemison  San Antonio         True
# 3  Billy    98       96       88  Jemison  San Antonio         True
# 4    Ada    77       92       98  Jemison  San Antonio        False
#
#    english_honors  reading_honors  all_honors
# 0           False           False       False
# 1           False           False       False
# 2           False            True       False
# 3            True           False       False
# 4            True            True       False

# %%
# Another way to produce our "all_honors" column
df["all_honors"] = (df.english >= 90) & (df.math >= 90) & (df.reading >= 90)
df.head()
# Out:
#     name  math  english  reading   cohort       campus  math_honors  \
# 0  Sally    62       85       80  Jemison  San Antonio        False
# 1   Jane    88       79       67  Jemison  San Antonio        False
# 2  Suzie    94       74       95  Jemison  San Antonio         True
# 3  Billy    98       96       88  Jemison  San Antonio         True
# 4    Ada    77       92       98  Jemison  San Antonio        False
#
#    english_honors  reading_honors  all_honors
# 0           False           False       False
# 1           False           False       False
# 2           False            True       False
# 3            True           False       False
# 4            True            True       False

# %%
df["overall_average"] = (df.math + df.english + df.reading) / 3
df.head()
# Out:
#     name  math  english  reading   cohort       campus  math_honors  \
# 0  Sally    62       85       80  Jemison  San Antonio        False
# 1   Jane    88       79       67  Jemison  San Antonio        False
# 2  Suzie    94       74       95  Jemison  San Antonio         True
# 3  Billy    98       96       88  Jemison  San Antonio         True
# 4    Ada    77       92       98  Jemison  San Antonio        False
#
#    english_honors  reading_honors  all_honors  overall_average
# 0           False           False       False        75.666667
# 1           False           False       False        78.000000
# 2           False            True       False        87.666667
# 3            True           False       False        94.000000
# 4            True            True       False        89.000000

# %%
# to view only a specific set of columns:
columns = ["name", "math", "reading", "english"]
df[columns].head()
# Out:
#     name  math  reading  english
# 0  Sally    62       80       85
# 1   Jane    88       67       79
# 2  Suzie    94       95       74
# 3  Billy    98       88       96
# 4    Ada    77       98       92

# %%
# double brackets produce the same result as above w/o a variable
df[["name", "math", "reading", "english"]]
# Out:
#        name  math  reading  english
# 0     Sally    62       80       85
# 1      Jane    88       67       79
# 2     Suzie    94       95       74
# 3     Billy    98       88       96
# 4       Ada    77       98       92
# 5      John    79       93       76
# 6    Thomas    82       81       64
# 7     Marie    93       90       63
# 8    Albert    92       87       62
# 9   Richard    69       94       80
# 10    Isaac    92       93       99
# 11     Alan    92       72       62

# %%
# How to drop columns
cols_to_drop = ["campus", "cohort"]

# Since drop doesn't change the original dataframe, we'll reassign the df
df = df.drop(columns=cols_to_drop)
df.head()
# Out:
#     name  math  english  reading  math_honors  english_honors  reading_honors  \
# 0  Sally    62       85       80        False           False           False
# 1   Jane    88       79       67        False           False           False
# 2  Suzie    94       74       95         True           False            True
# 3  Billy    98       96       88         True            True           False
# 4    Ada    77       92       98        False            True            True
#
#    all_honors  overall_average
# 0       False        75.666667
# 1       False        78.000000
# 2       False        87.666667
# 3       False        94.000000
# 4       False        89.000000

# %%
# .tail peeks at the end of the df
df.tail()
# Out:
#        name  math  english  reading  math_honors  english_honors  \
# 7     Marie    93       63       90         True           False
# 8    Albert    92       62       87         True           False
# 9   Richard    69       80       94        False           False
# 10    Isaac    92       99       93         True            True
# 11     Alan    92       62       72         True           False
#
#     reading_honors  all_honors  overall_average
# 7             True       False        82.000000
# 8            False       False        80.333333
# 9             True       False        81.000000
# 10            True        True        94.666667
# 11           False       False        75.333333

# %%
# .sample samples the df randomly
df.sample(5)
# Out:
#       name  math  english  reading  math_honors  english_honors  \
# 9  Richard    69       80       94        False           False
# 5     John    79       76       93        False           False
# 1     Jane    88       79       67        False           False
# 7    Marie    93       63       90         True           False
# 8   Albert    92       62       87         True           False
#
#    reading_honors  all_honors  overall_average
# 9            True       False        81.000000
# 5            True       False        82.666667
# 1           False       False        78.000000
# 7            True       False        82.000000
# 8           False       False        80.333333

# %%
# If you have a series/array of booleans, you can filter your results
df[df.name == "Jane"]
# Out:
#    name  math  english  reading  math_honors  english_honors  reading_honors  \
# 1  Jane    88       79       67        False           False           False
#
#    all_honors  overall_average
# 1       False             78.0

# %%
df[(df.name == "Jane") | (df.name == "Marie")]
# Out:
#     name  math  english  reading  math_honors  english_honors  reading_honors  \
# 1   Jane    88       79       67        False           False           False
# 7  Marie    93       63       90         True           False            True
#
#    all_honors  overall_average
# 1       False             78.0
# 7       False             82.0

# %%
# The | or & operators here return a series of booleans
(df.name == "Jane") | (df.name == "Marie")
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# Name: name, dtype: bool

# %% [markdown]
# ## ORs and ANDs in programming
# - ANDs limit our possibilities:
#     - allergic to peanuts and shellfish and dairy and bell peppers
#     - you limit your results
# - ORs expand your possibilities
#     - I'm good with pizza or pasta or salad or curry or sandwich or.....

# %%
# Only show folks who are passing english and math
df[(df.math >= 70) & (df.english >= 70)]
# Out:
#      name  math  english  reading  math_honors  english_honors  \
# 1    Jane    88       79       67        False           False
# 2   Suzie    94       74       95         True           False
# 3   Billy    98       96       88         True            True
# 4     Ada    77       92       98        False            True
# 5    John    79       76       93        False           False
# 10  Isaac    92       99       93         True            True
#
#     reading_honors  all_honors  overall_average
# 1            False       False        78.000000
# 2             True       False        87.666667
# 3            False       False        94.000000
# 4             True       False        89.000000
# 5             True       False        82.666667
# 10            True        True        94.666667

# %%
# With an OR, it only takes one true to make the entire expression true
df[(df.math >= 70) | (df.english >= 70)]
# Out:
#        name  math  english  reading  math_honors  english_honors  \
# 0     Sally    62       85       80        False           False
# 1      Jane    88       79       67        False           False
# 2     Suzie    94       74       95         True           False
# 3     Billy    98       96       88         True            True
# 4       Ada    77       92       98        False            True
# 5      John    79       76       93        False           False
# 6    Thomas    82       64       81        False           False
# 7     Marie    93       63       90         True           False
# 8    Albert    92       62       87         True           False
# 9   Richard    69       80       94        False           False
# 10    Isaac    92       99       93         True            True
# 11     Alan    92       62       72         True           False
#
#     reading_honors  all_honors  overall_average
# 0            False       False        75.666667
# 1            False       False        78.000000
# 2             True       False        87.666667
# 3            False       False        94.000000
# 4             True       False        89.000000
# 5             True       False        82.666667
# 6            False       False        75.666667
# 7             True       False        82.000000
# 8            False       False        80.333333
# 9             True       False        81.000000
# 10            True        True        94.666667
# 11           False       False        75.333333

# %%
# The code or variable that produces the series of booleans goes in the square braces
# SELECT * from df where name startswith("S")
df[df.name.str.startswith("S")]
# Out:
#     name  math  english  reading  math_honors  english_honors  reading_honors  \
# 0  Sally    62       85       80        False           False           False
# 2  Suzie    94       74       95         True           False            True
#
#    all_honors  overall_average
# 0       False        75.666667
# 2       False        87.666667

# %%
# Sorting
df.sort_values(by="english").head() # defaults to ascending order
# Out:
#       name  math  english  reading  math_honors  english_honors  \
# 8   Albert    92       62       87         True           False
# 11    Alan    92       62       72         True           False
# 7    Marie    93       63       90         True           False
# 6   Thomas    82       64       81        False           False
# 2    Suzie    94       74       95         True           False
#
#     reading_honors  all_honors  overall_average
# 8            False       False        80.333333
# 11           False       False        75.333333
# 7             True       False        82.000000
# 6            False       False        75.666667
# 2             True       False        87.666667

# %%
df.sort_values(by="english", ascending=False).head()
# Out:
#        name  math  english  reading  math_honors  english_honors  \
# 10    Isaac    92       99       93         True            True
# 3     Billy    98       96       88         True            True
# 4       Ada    77       92       98        False            True
# 0     Sally    62       85       80        False           False
# 9   Richard    69       80       94        False           False
#
#     reading_honors  all_honors  overall_average
# 10            True        True        94.666667
# 3            False       False        94.000000
# 4             True       False        89.000000
# 0            False       False        75.666667
# 9             True       False        81.000000

# %%
# Sorting by multiple columns
df = df.sort_values(by=["english", "math", "reading"])
df
# Out:
#        name  math  english  reading  math_honors  english_honors  \
# 11     Alan    92       62       72         True           False
# 8    Albert    92       62       87         True           False
# 7     Marie    93       63       90         True           False
# 6    Thomas    82       64       81        False           False
# 2     Suzie    94       74       95         True           False
# 5      John    79       76       93        False           False
# 1      Jane    88       79       67        False           False
# 9   Richard    69       80       94        False           False
# 0     Sally    62       85       80        False           False
# 4       Ada    77       92       98        False            True
# 3     Billy    98       96       88         True            True
# 10    Isaac    92       99       93         True            True
#
#     reading_honors  all_honors  overall_average
# 11           False       False        75.333333
# 8            False       False        80.333333
# 7             True       False        82.000000
# 6            False       False        75.666667
# 2             True       False        87.666667
# 5             True       False        82.666667
# 1            False       False        78.000000
# 9             True       False        81.000000
# 0            False       False        75.666667
# 4             True       False        89.000000
# 3            False       False        94.000000
# 10            True        True        94.666667

# %% [markdown]
# ## Chaining methods on a dataframe
# - Chaining ain't new: think of string method chaining
# - As long as your method returns a dataframe, you can attach another df method

# %%
"bANANA".swapcase().lower().swapcase()
# Out:
# 'BANANA'

# %%
# if a method returns a df, we can attach another df method onto that
df.sort_values(by="all_honors").sort_values(by="name").head(10).head(5)
# Out:
#       name  math  english  reading  math_honors  english_honors  \
# 4      Ada    77       92       98        False            True
# 11    Alan    92       62       72         True           False
# 8   Albert    92       62       87         True           False
# 3    Billy    98       96       88         True            True
# 10   Isaac    92       99       93         True            True
#
#     reading_honors  all_honors  overall_average
# 4             True       False        89.000000
# 11           False       False        75.333333
# 8            False       False        80.333333
# 3            False       False        94.000000
# 10            True        True        94.666667

# %%
# Methods execute from left to right
# Functions execute from inside out (right to left)

# %%
df[["name", "english"]].sort_values(by="english", ascending=False).head(10).english >= 90
# Out:
# 10     True
# 3      True
# 4      True
# 0     False
# 9     False
# 1     False
# 5     False
# 2     False
# 6     False
# 7     False
# Name: english, dtype: bool

# %%
df.head()
# Out:
#       name  math  english  reading  math_honors  english_honors  \
# 11    Alan    92       62       72         True           False
# 8   Albert    92       62       87         True           False
# 7    Marie    93       63       90         True           False
# 6   Thomas    82       64       81        False           False
# 2    Suzie    94       74       95         True           False
#
#     reading_honors  all_honors  overall_average
# 11           False       False        75.333333
# 8            False       False        80.333333
# 7             True       False        82.000000
# 6            False       False        75.666667
# 2             True       False        87.666667

# %%
# Renaming columns using a dictionary
cols_to_rename = {
    "math": "math_grade",
    "reading": "reading_grade",
    "english": "english_grade"
}
cols_to_rename
# Out:
# {'math': 'math_grade', 'reading': 'reading_grade', 'english': 'english_grade'}

# %%
# df.rename(columns={})
# The dictionary has colunns to rename
df = df.rename(columns=cols_to_rename)
df
# Out:
#        name  math_grade  english_grade  reading_grade  math_honors  \
# 11     Alan          92             62             72         True
# 8    Albert          92             62             87         True
# 7     Marie          93             63             90         True
# 6    Thomas          82             64             81        False
# 2     Suzie          94             74             95         True
# 5      John          79             76             93        False
# 1      Jane          88             79             67        False
# 9   Richard          69             80             94        False
# 0     Sally          62             85             80        False
# 4       Ada          77             92             98        False
# 3     Billy          98             96             88         True
# 10    Isaac          92             99             93         True
#
#     english_honors  reading_honors  all_honors  overall_average
# 11           False           False       False        75.333333
# 8            False           False       False        80.333333
# 7            False            True       False        82.000000
# 6            False           False       False        75.666667
# 2            False            True       False        87.666667
# 5            False            True       False        82.666667
# 1            False           False       False        78.000000
# 9            False            True       False        81.000000
# 0            False           False       False        75.666667
# 4             True            True       False        89.000000
# 3             True           False       False        94.000000
# 10            True            True        True        94.666667

# %%
type(pd.DataFrame({"name": students}))
# Out:
# pandas.core.frame.DataFrame
